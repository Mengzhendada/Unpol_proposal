# %%
import yaml

# %%
data = {
    'dependent_variables': [
        {
            'header': {
                'title': "COMPASS, Deu  -  PmKm   0.100000 < x < 0.210000 , 0.400000 < |#it{z}| < 0.600000",
                'titlepy': "COMPASS, Deu - PmKm \\\\ 0.100000 < x < 0.210000 , 0.400000 < z < 0.600000",
                'xlabel': "#it{P}_{hT} [GeV]",
                'xlabelpy': "$P_{hT} \\rm{ [GeV]}$",
                'ylabel': "M^{h^{-}}#left(x, z, |{P}_{hT}|^2, Q^2 #right)",
                'ylabelpy': "$M^{h^{-}}\\left(x, z, |{P}_{hT}|^2, Q^2 \\right)$"
            },
            'qualifiers': [
                {'name': 'process', 'value': 'SIDIS'},
                {'name': 'observable', 'value': '(dsigma/dxdzdQ2dPhT2)/dsigmaDIS'},
                {'name': 'target_isoscalarity', 'value': 0.5},
                {'name': 'hadron', 'value': 'HD'},
                {'name': 'charge', 'value': -1},
                {'name': 'prefactor', 'value': 1},
                {'name': 'Vs', 'value': 17.325},
                {'name': 'Q', 'low': 2.6457513, 'high': 4, 'integrate': True},
                {'name': 'x', 'low': 0.1, 'high': 0.21, 'integrate': True},
                {'name': 'z', 'low': 0.4, 'high': 0.6, 'integrate': True},
                {'name': 'PS_reduction', 'W': 5, 'ymin': 0.1, 'ymax': 0.9}
            ],
            'values': [
                {'errors': [{'label': 'unc', 'value': 0.0232}, {'label': 'mult', 'value': 0.008649336}], 'value': 0.7835},
                {'errors': [{'label': 'unc', 'value': 0.0222}, {'label': 'mult', 'value': 0.008609096}], 'value': 0.73}
                # Add more values as needed
            ]
        }
    ],
    'independent_variables': [
        {
            'header': {'name': 'PhT', 'units': 'GeV'},
            'values': [
                {'high': 0.2, 'low': 0.14142136, 'value': 0.17320508, 'factor': 2.9289322},
                {'high': 0.24494897, 'low': 0.2, 'value': 0.22405357, 'factor': 2.2474487}
                # Add more values as needed
            ]
        },
        {
            'header': {'name': 'x'},
            'values': [
                {'high': 0.21, 'low': 0.1, 'value': 0.1488},
                {'high': 0.21, 'low': 0.1, 'value': 0.1488}
                # Repeat as necessary
            ]
        },
        {
            'header': {'name': 'z'},
            'values': [
                {'high': 0.6, 'low': 0.4, 'value': 0.478},
                {'high': 0.6, 'low': 0.4, 'value': 0.478}
                # Repeat as necessary
            ]
        },
        {
            'header': {'name': 'y'},
            'values': [
                {'high': 0.9, 'low': 0.1, 'value': 0.23},
                {'high': 0.9, 'low': 0.1, 'value': 0.23}
                # Repeat as necessary
            ]
        },
        {
            'header': {'name': 'Q2'},
            'values': [
                {'high': 16, 'low': 7, 'value': 9.8},
                {'high': 16, 'low': 7, 'value': 9.8}
                # Repeat as necessary
            ]
        }
    ]
}

# %%
with open('output.yaml', 'w') as file:
    yaml.dump(data, file, default_flow_style=False, sort_keys=False)
